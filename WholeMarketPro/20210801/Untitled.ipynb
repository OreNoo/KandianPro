# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
# Out:
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-1-d5c609e1832c> in <module>
#       2 os.environ["kdconfig"] = "database.yaml"
#       3 os.environ["dbsync_config"] = "sync_config.ini"
# ----> 4 from kd_backtest.api import *
#
# ~/env4tiho_py36/lib/python3.6/site-packages/kd_backtest/api.py in <module>
#       1 from kd_backtest.common.constant import *
# ----> 2 from kd_backtest.strategy.strategy_policy import StrategyPolicy
#       3 from kd_backtest.simulation.utils import get_position, get_market_data, SimulationConfig, simulate_trade_transaction, update_close_position_mkt_value, cal_trade_signal, SimulationConfig
#       4 from kd_backtest.ensemble.ensemblemodel import *
#
# ~/env4tiho_py36/lib/python3.6/site-packages/kd_backtest/strategy/strategy_policy.py in <module>
#      12 from qsdata.api import *
#      13 from kd_backtest.common.constant import *
# ---> 14 from kd_backtest.simulation.utils import get_market_data
#      15 from kd_backtest.simulation.utils import simulation
#      16 from kd_backtest.simulation.utils import index_performance
#
# ~/env4tiho_py36/lib/python3.6/site-packages/kd_backtest/simulation/utils.py in <module>
#       5 from kd_backtest.common.constant import *
#       6 from qsdata.api import *
# ----> 7 from sync.kd_logging import logger
#       8 import cvxpy as cvx
#       9 from sklearn.linear_model import LinearRegression
#
# ~/env4tiho_py36/lib/python3.6/site-packages/sync/kd_logging.py in <module>
#      11
#      12
# ---> 13 logging.config.fileConfig(dbsync_config.config)
#      14 logger = logging.getLogger("kd_logger")
#      15
#
# /usr/local/python/lib/python3.6/logging/config.py in fileConfig(fname, defaults, disable_existing_loggers)
#      82         del logging._handlerList[:]
#      83         # Handlers add themselves to logging._handlers
# ---> 84         handlers = _install_handlers(cp, formatters)
#      85         _install_loggers(cp, handlers, disable_existing_loggers)
#      86     finally:
#
# /usr/local/python/lib/python3.6/logging/config.py in _install_handlers(cp, formatters)
#     146         args = section["args"]
#     147         args = eval(args, vars(logging))
# --> 148         h = klass(*args)
#     149         if "level" in section:
#     150             level = section["level"]
#
# /usr/local/python/lib/python3.6/logging/handlers.py in __init__(self, filename, mode, maxBytes, backupCount, encoding, delay)
#     148         if maxBytes > 0:
#     149             mode = 'a'
# --> 150         BaseRotatingHandler.__init__(self, filename, mode, encoding, delay)
#     151         self.maxBytes = maxBytes
#     152         self.backupCount = backupCount
#
# /usr/local/python/lib/python3.6/logging/handlers.py in __init__(self, filename, mode, encoding, delay)
#      55         Use the specified filename for streamed logging
#      56         """
# ---> 57         logging.FileHandler.__init__(self, filename, mode, encoding, delay)
#      58         self.mode = mode
#      59         self.encoding = encoding
#
# /usr/local/python/lib/python3.6/logging/__init__.py in __init__(self, filename, mode, encoding, delay)
#    1028             self.stream = None
#    1029         else:
# -> 1030             StreamHandler.__init__(self, self._open())
#    1031
#    1032     def close(self):
#
# /usr/local/python/lib/python3.6/logging/__init__.py in _open(self)
#    1057         Return the resulting stream.
#    1058         """
# -> 1059         return open(self.baseFilename, self.mode, encoding=self.encoding)
#    1060
#    1061     def emit(self, record):
#
# PermissionError: [Errno 13] Permission denied: '/home/zhupeng/20210304/kd_strategy.log'
