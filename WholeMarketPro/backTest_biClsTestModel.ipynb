# %% [markdown]
# ## biClsModel_Test_D1

# %% [markdown]
# ## biClsModel_Test_D2

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210816_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test_D2/",
                             turnover=0.3,
                             adj=3,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test_D2/20210816_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-16 13:08:09dddd strategy_policy.py INFO  start to load prediction
# 2021-08-16 13:09:42dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-16 13:09:42dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-16 13:10:36dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-16 13:10:37dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002656.SZ,dt=2020-01-10,trade_type=1,股票停牌！
# 2021-08-16 13:10:37dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600130.SH,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-16 13:10:37dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002137.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-16 13:10:39dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-16 13:10:39dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-16 13:10:39dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# ...

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210816_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test_D2/",
                             turnover=0.3,
                             adj=5,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test_D2/20210816_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-16 13:25:07dddd strategy_policy.py INFO  start to load prediction
# 2021-08-16 13:26:05dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-16 13:26:05dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-16 13:27:40dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-16 13:27:41dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002656.SZ,dt=2020-01-10,trade_type=1,股票停牌！
# 2021-08-16 13:27:41dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600130.SH,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-16 13:27:41dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002137.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-16 13:27:43dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-16 13:27:43dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-16 13:27:43dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# ...

# %% [markdown]
# ## biClsModel_Test_D3

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210816_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test_D3/",
                             turnover=0.3,
                             adj=3,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test_D3/20210816_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Duplicate key in file PosixPath('/home/tianhao/env4tiho_py36/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'), line 400 ('axes.unicode_minus: True  # use Unicode for the minus symbol rather than hyphen.  See')
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 2021-08-16 10:49:56dddd strategy_policy.py INFO  start to load prediction
# 2021-08-16 10:51:59dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# ...

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210816_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test_D3/",
                             turnover=0.3,
                             adj=5,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test_D3/20210816_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-16 11:12:13dddd strategy_policy.py INFO  start to load prediction
# 2021-08-16 11:13:33dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-16 11:13:33dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-16 11:14:42dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-16 11:14:43dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002277.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-16 11:14:46dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-16 11:14:46dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-16 11:14:46dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-16 11:14:48dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# 2021-08-16 11:14:48dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-14 ..
# ...

# %% [markdown]
# ## biClsModel_Test_D4

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210816_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test_D4/",
                             turnover=0.3,
                             adj=3,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test_D4/20210816_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Duplicate key in file PosixPath('/home/tianhao/env4tiho_py36/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'), line 400 ('axes.unicode_minus: True  # use Unicode for the minus symbol rather than hyphen.  See')
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 2021-08-18 15:17:11dddd strategy_policy.py INFO  start to load prediction
# 2021-08-18 15:18:48dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# ...

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210816_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test_D4/",
                             turnover=0.3,
                             adj=5,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test_D4/20210816_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-18 15:37:10dddd strategy_policy.py INFO  start to load prediction
# 2021-08-18 15:38:21dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-18 15:38:21dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-18 15:39:28dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-18 15:39:32dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-18 15:39:32dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-18 15:39:32dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-18 15:39:33dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# 2021-08-18 15:39:33dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-14 ..
# 2021-08-18 15:39:34dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-14 ..
# ...

# %% [markdown]
# 全属性
#
# d = 0.001
# * 0.20
# * 0.21
#
# d = 0.01
# * 0.201057
# * 0.195095
#
# d = 0.1
# * 0.180985
# * 0.189368
#
# `去除'vwap', 'vwap_mean3','vwap_mean5', 'vwap_mean10', 'vwap_mean20'` `d = 0.1` `模型参数：64 32 16 1` `window=5`
#
# d = 0.1
# * 0.196700
# * 0.226929
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## biClsModel_Test2_D4

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210818_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test2_D4/",
                             turnover=0.3,
                             adj=3,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test2_D4/20210818_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-18 15:53:12dddd strategy_policy.py INFO  start to load prediction
# 2021-08-18 15:54:44dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-18 15:54:44dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-18 15:55:37dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-18 15:55:38dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002277.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-18 15:55:39dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000679.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-18 15:55:40dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-18 15:55:40dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-18 15:55:40dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-18 15:55:42dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# ...

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210818_tiho",
                             model_root_dir="./result4tiho/biClsModel_Test2_D4/",
                             turnover=0.3,
                             adj=5,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/biClsModel_Test2_D4/20210818_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-18 16:13:19dddd strategy_policy.py INFO  start to load prediction
# 2021-08-18 16:14:24dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-18 16:14:24dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-18 16:15:19dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-18 16:15:20dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002277.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-18 16:15:20dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000679.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-18 16:15:22dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-18 16:15:22dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-18 16:15:22dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-18 16:15:24dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# ...

# %% [markdown]
# 去除vwap、vwap_mean5
#
# d = 0.001:
# * 0.182136
# * 0.205498
#
# d = 0.1:
# * 0.229185
# * 0.205955
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
