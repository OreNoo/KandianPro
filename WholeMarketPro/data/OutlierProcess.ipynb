# %% [markdown]
# # 数据分析
# 1. 异常值处理 删除异常值
# 2. 删除数据量过少的股票的数据

# %%
# 读取文件
import pandas as pd
from tqdm import tqdm
df = pd.read_csv('data.csv')
df
# Out:
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Duplicate key in file PosixPath('/home/tianhao/env4tiho_py36/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'), line 400 ('axes.unicode_minus: True  # use Unicode for the minus symbol rather than hyphen.  See')
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                  dt     kdcode      volume      turnover    turn  pct_chg  \
# 0        2016-01-04  000001.SZ  56349787.0  6.603762e+08  0.4774    -5.51
# 1        2016-01-05  000001.SZ  66326995.0  7.555314e+08  0.5619     0.61
# 2        2016-01-06  000001.SZ  51570644.0  5.916985e+08  0.4369     1.14
# 3        2016-01-07  000001.SZ  17476110.0  1.948695e+08  0.1481    -5.12
# 4        2016-01-08  000001.SZ  74752758.0  8.313345e+08  0.6333     1.64
# ...             ...        ...         ...           ...     ...      ...
# 4580328  2021-07-26  689009.SH   2008700.0  1.309806e+08  3.3200    -1.32
# 4580329  2021-07-27  689009.SH   1835700.0  1.245621e+08  3.0300    -0.04
# 4580330  2021-07-28  689009.SH   1741400.0  1.142330e+08  2.8800     0.48
# 4580331  2021-07-29  689009.SH   1619800.0  1.121369e+08  2.6800     0.84
# 4580332  2021-07-30  689009.SH   1438500.0  9.605356e+07  2.3800     0.53
#
#               vwap  trade_status   adj_close    adj_open    adj_high  \
# 0        11.719231             0  935.197763  990.500720  992.976972
# 1        11.391008             0  940.975684  930.245260  955.007778
# 2        11.473553             0  951.706109  942.626519  954.182361
# 3        11.150622             0  903.006490  941.801102  941.801102
# 4        11.121122             0  917.864001  925.292756  931.896094
# ...            ...           ...         ...         ...         ...
# 4580328  65.206660             0   67.180000   67.860000   67.860000
# 4580329  67.855344             0   67.150000   66.000000   70.970000
# 4580330  65.598397             0   67.470000   66.010000   67.590000
# 4580331  69.228825             0   68.040000   67.800000   70.550000
# 4580332  66.773413             0   68.400000   67.520000   68.840000
#
#             adj_low
# 0        926.943591
# 1        920.340253
# 2        940.150267
# 3        900.530238
# 4        899.704821
# ...             ...
# 4580328   63.000000
# 4580329   65.160000
# 4580330   63.010000
# 4580331   67.130000
# 4580332   65.500000
#
# [4580333 rows x 12 columns]

# %% [markdown]
# ## 1. 异常值处理
#
# 这里使用了`线箱法`处理异常值
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# 这里我们使用筛去了`x > Q3 + 5(Q3 - Q1)`与`x < Q3 - 3(Q3 - Q1)`的数据
#
# ### 1.1 对于`volume`的异常值处理

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 密度图
 
# Draw Plot
sns.kdeplot(df['volume'], shade=True, color="g", label="volume", alpha=.7)

# Decoration
plt.title('volume probability density distribution')
plt.legend()
plt.show()

# %%
df['volume'].describe()
# Out:
# count    4.580333e+06
# mean     1.402015e+07
# std      3.295045e+07
# min      1.000000e+02
# 25%      2.463927e+06
# 50%      5.755484e+06
# 75%      1.384698e+07
# max      4.034860e+09
# Name: volume, dtype: float64

# %%
q1 = df['volume'].quantile(0.25)
q2 = df['volume'].quantile()
q3 = df['volume'].quantile(0.75)
max_outlier = q3 + 5 * (q3 - q1)
min_outlier = q1 - 3 * (q3 - q1)
df = df[(df['volume'] <= max_outlier) & (df['volume'] >= min_outlier)]
df
# Out:
#                  dt     kdcode      volume      turnover    turn  pct_chg  \
# 0        2016-01-04  000001.SZ  56349787.0  6.603762e+08  0.4774    -5.51
# 1        2016-01-05  000001.SZ  66326995.0  7.555314e+08  0.5619     0.61
# 2        2016-01-06  000001.SZ  51570644.0  5.916985e+08  0.4369     1.14
# 3        2016-01-07  000001.SZ  17476110.0  1.948695e+08  0.1481    -5.12
# 6        2016-01-12  000001.SZ  56164230.0  6.059708e+08  0.4758     0.46
# ...             ...        ...         ...           ...     ...      ...
# 4580328  2021-07-26  689009.SH   2008700.0  1.309806e+08  3.3200    -1.32
# 4580329  2021-07-27  689009.SH   1835700.0  1.245621e+08  3.0300    -0.04
# 4580330  2021-07-28  689009.SH   1741400.0  1.142330e+08  2.8800     0.48
# 4580331  2021-07-29  689009.SH   1619800.0  1.121369e+08  2.6800     0.84
# 4580332  2021-07-30  689009.SH   1438500.0  9.605356e+07  2.3800     0.53
#
#               vwap  trade_status   adj_close    adj_open    adj_high  \
# 0        11.719231             0  935.197763  990.500720  992.976972
# 1        11.391008             0  940.975684  930.245260  955.007778
# 2        11.473553             0  951.706109  942.626519  954.182361
# 3        11.150622             0  903.006490  941.801102  941.801102
# 6        10.789266             0  892.276066  893.926900  900.530238
# ...            ...           ...         ...         ...         ...
# 4580328  65.206660             0   67.180000   67.860000   67.860000
# 4580329  67.855344             0   67.150000   66.000000   70.970000
# 4580330  65.598397             0   67.470000   66.010000   67.590000
# 4580331  69.228825             0   68.040000   67.800000   70.550000
# 4580332  66.773413             0   68.400000   67.520000   68.840000
#
#             adj_low
# 0        926.943591
# 1        920.340253
# 2        940.150267
# 3        900.530238
# 6        878.243972
# ...             ...
# 4580328   63.000000
# 4580329   65.160000
# 4580330   63.010000
# 4580331   67.130000
# 4580332   65.500000
#
# [4443324 rows x 12 columns]

# %%
# Draw Plot
sns.kdeplot(df['volume'], shade=True, color="g", label="volume", alpha=.7)

# Decoration
plt.title('volume probability density distribution')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.2 对于`turnover`的异常值处理

# %%
# Draw Plot
sns.kdeplot(df['turnover'], shade=True, color="b", label="turnover", alpha=.7)

# Decoration
plt.title('turnover probability density distribution')
plt.legend()
plt.show()

# %%
df['turnover'].describe()
# Out:
# count    4.443324e+06
# mean     1.393150e+08
# std      2.695434e+08
# min      2.108000e+03
# 25%      2.821006e+07
# 50%      6.420317e+07
# 75%      1.495593e+08
# max      1.849878e+10
# Name: turnover, dtype: float64

# %%
q1 = df['turnover'].quantile(0.25)
q2 = df['turnover'].quantile()
q3 = df['turnover'].quantile(0.75)
max_outlier = q3 + 5 * (q3 - q1)
min_outlier = q1 - 3 * (q3 - q1)
df = df[(df['turnover'] <= max_outlier) & (df['turnover'] >= min_outlier)]
df
# Out:
#                  dt     kdcode      volume      turnover    turn  pct_chg  \
# 0        2016-01-04  000001.SZ  56349787.0  6.603762e+08  0.4774    -5.51
# 1        2016-01-05  000001.SZ  66326995.0  7.555314e+08  0.5619     0.61
# 2        2016-01-06  000001.SZ  51570644.0  5.916985e+08  0.4369     1.14
# 3        2016-01-07  000001.SZ  17476110.0  1.948695e+08  0.1481    -5.12
# 6        2016-01-12  000001.SZ  56164230.0  6.059708e+08  0.4758     0.46
# ...             ...        ...         ...           ...     ...      ...
# 4580328  2021-07-26  689009.SH   2008700.0  1.309806e+08  3.3200    -1.32
# 4580329  2021-07-27  689009.SH   1835700.0  1.245621e+08  3.0300    -0.04
# 4580330  2021-07-28  689009.SH   1741400.0  1.142330e+08  2.8800     0.48
# 4580331  2021-07-29  689009.SH   1619800.0  1.121369e+08  2.6800     0.84
# 4580332  2021-07-30  689009.SH   1438500.0  9.605356e+07  2.3800     0.53
#
#               vwap  trade_status   adj_close    adj_open    adj_high  \
# 0        11.719231             0  935.197763  990.500720  992.976972
# 1        11.391008             0  940.975684  930.245260  955.007778
# 2        11.473553             0  951.706109  942.626519  954.182361
# 3        11.150622             0  903.006490  941.801102  941.801102
# 6        10.789266             0  892.276066  893.926900  900.530238
# ...            ...           ...         ...         ...         ...
# 4580328  65.206660             0   67.180000   67.860000   67.860000
# 4580329  67.855344             0   67.150000   66.000000   70.970000
# 4580330  65.598397             0   67.470000   66.010000   67.590000
# 4580331  69.228825             0   68.040000   67.800000   70.550000
# 4580332  66.773413             0   68.400000   67.520000   68.840000
#
#             adj_low
# 0        926.943591
# 1        920.340253
# 2        940.150267
# 3        900.530238
# 6        878.243972
# ...             ...
# 4580328   63.000000
# 4580329   65.160000
# 4580330   63.010000
# 4580331   67.130000
# 4580332   65.500000
#
# [4343012 rows x 12 columns]

# %%
# Draw Plot
sns.kdeplot(df['turnover'], shade=True, color="b", label="turnover", alpha=.7)

# Decoration
plt.title('turnover probability density distribution')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.3 对于`vwap`的异常值处理

# %%
# Draw Plot
sns.kdeplot(df['vwap'], shade=True, color="y", label="vwap", alpha=.7)

# Decoration
plt.title('vwap probability density distribution')
plt.legend()
plt.show()

# %%
df['vwap'].describe()
# Out:
# count    4.343012e+06
# mean     1.743910e+01
# std      2.370937e+01
# min      6.100000e-01
# 25%      6.524328e+00
# 50%      1.118978e+01
# 75%      1.991053e+01
# max      1.421385e+03
# Name: vwap, dtype: float64

# %%
q1 = df['vwap'].quantile(0.25)
q2 = df['vwap'].quantile()
q3 = df['vwap'].quantile(0.75)
max_outlier = q3 + 5 * (q3 - q1)
min_outlier = q1 - 3 * (q3 - q1)
df = df[(df['vwap'] <= max_outlier) & (df['vwap'] >= min_outlier)]
df
# Out:
#                  dt     kdcode      volume      turnover    turn  pct_chg  \
# 0        2016-01-04  000001.SZ  56349787.0  6.603762e+08  0.4774    -5.51
# 1        2016-01-05  000001.SZ  66326995.0  7.555314e+08  0.5619     0.61
# 2        2016-01-06  000001.SZ  51570644.0  5.916985e+08  0.4369     1.14
# 3        2016-01-07  000001.SZ  17476110.0  1.948695e+08  0.1481    -5.12
# 6        2016-01-12  000001.SZ  56164230.0  6.059708e+08  0.4758     0.46
# ...             ...        ...         ...           ...     ...      ...
# 4580328  2021-07-26  689009.SH   2008700.0  1.309806e+08  3.3200    -1.32
# 4580329  2021-07-27  689009.SH   1835700.0  1.245621e+08  3.0300    -0.04
# 4580330  2021-07-28  689009.SH   1741400.0  1.142330e+08  2.8800     0.48
# 4580331  2021-07-29  689009.SH   1619800.0  1.121369e+08  2.6800     0.84
# 4580332  2021-07-30  689009.SH   1438500.0  9.605356e+07  2.3800     0.53
#
#               vwap  trade_status   adj_close    adj_open    adj_high  \
# 0        11.719231             0  935.197763  990.500720  992.976972
# 1        11.391008             0  940.975684  930.245260  955.007778
# 2        11.473553             0  951.706109  942.626519  954.182361
# 3        11.150622             0  903.006490  941.801102  941.801102
# 6        10.789266             0  892.276066  893.926900  900.530238
# ...            ...           ...         ...         ...         ...
# 4580328  65.206660             0   67.180000   67.860000   67.860000
# 4580329  67.855344             0   67.150000   66.000000   70.970000
# 4580330  65.598397             0   67.470000   66.010000   67.590000
# 4580331  69.228825             0   68.040000   67.800000   70.550000
# 4580332  66.773413             0   68.400000   67.520000   68.840000
#
#             adj_low
# 0        926.943591
# 1        920.340253
# 2        940.150267
# 3        900.530238
# 6        878.243972
# ...             ...
# 4580328   63.000000
# 4580329   65.160000
# 4580330   63.010000
# 4580331   67.130000
# 4580332   65.500000
#
# [4279753 rows x 12 columns]

# %%
# Draw Plot
sns.kdeplot(df['vwap'], shade=True, color="y", label="vwap", alpha=.7)

# Decoration
plt.title('vwap probability density distribution')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.4 对于`adj_open`的异常值处理

# %%
# Draw Plot
sns.kdeplot(df['adj_open'], shade=True, color="black", label="adj_open", alpha=.7)

# Decoration
plt.title('adj_open probability density distribution')
plt.legend()
plt.show()

# %%
df['adj_open'].describe()
# Out:
# count    4.279753e+06
# mean     1.208795e+02
# std      1.974108e+03
# min      1.082400e+00
# 25%      2.163753e+01
# 50%      3.786903e+01
# 75%      6.610000e+01
# max      2.379521e+05
# Name: adj_open, dtype: float64

# %%
q1 = df['adj_open'].quantile(0.25)
q2 = df['adj_open'].quantile()
q3 = df['adj_open'].quantile(0.75)
max_outlier = q3 + 5 * (q3 - q1)
min_outlier = q1 - 5 * (q3 - q1)
df = df[(df['adj_open'] <= max_outlier) & (df['adj_open'] >= min_outlier)]
df
# Out:
#                  dt     kdcode     volume      turnover    turn  pct_chg  \
# 2588     2016-01-04  000004.SZ  2283380.0  9.767487e+07  2.7223 -10.0000
# 2589     2016-01-05  000004.SZ  3883664.0  1.505349e+08  4.6303  -6.3665
# 2590     2016-01-06  000004.SZ  2114757.0  8.257999e+07  2.5213   1.2927
# 2591     2016-01-07  000004.SZ   456900.0  1.651672e+07  0.5447 -10.0051
# 2592     2016-01-08  000004.SZ  3077465.0  1.071972e+08  3.6691   0.6239
# ...             ...        ...        ...           ...     ...      ...
# 4580328  2021-07-26  689009.SH  2008700.0  1.309806e+08  3.3200  -1.3200
# 4580329  2021-07-27  689009.SH  1835700.0  1.245621e+08  3.0300  -0.0400
# 4580330  2021-07-28  689009.SH  1741400.0  1.142330e+08  2.8800   0.4800
# 4580331  2021-07-29  689009.SH  1619800.0  1.121369e+08  2.6800   0.8400
# 4580332  2021-07-30  689009.SH  1438500.0  9.605356e+07  2.3800   0.5300
#
#               vwap  trade_status   adj_close    adj_open    adj_high  \
# 2588     42.776439             0  243.215104  270.239004  274.360296
# 2589     38.761049             0  227.730821  220.783500  240.742328
# 2590     39.049400             0  230.674601  227.259816  235.502400
# 2591     36.149518             0  207.595366  226.671060  226.671060
# 2592     34.832959             0  208.890629  206.829983  214.895940
# ...            ...           ...         ...         ...         ...
# 4580328  65.206660             0   67.180000   67.860000   67.860000
# 4580329  67.855344             0   67.150000   66.000000   70.970000
# 4580330  65.598397             0   67.470000   66.010000   67.590000
# 4580331  69.228825             0   68.040000   67.800000   70.550000
# 4580332  66.773413             0   68.400000   67.520000   68.840000
#
#             adj_low
# 2588     243.215104
# 2589     218.899481
# 2590     223.727280
# 2591     207.595366
# 2592     186.812279
# ...             ...
# 4580328   63.000000
# 4580329   65.160000
# 4580330   63.010000
# 4580331   67.130000
# 4580332   65.500000
#
# [4165820 rows x 12 columns]

# %% [markdown]
# ## 2. 删除数量过少的股票的数据

# %%
stocks_code = df['kdcode'].unique()
stocks_num = len(stocks_code)
"股票数量",stocks_num
# Out:
# ('股票数量', 4315)

# %%
# 根据股票代码划分数据
df_ = pd.DataFrame(columns = df.columns)
for i, stock_i in enumerate(tqdm(stocks_code)):
    stock_i_data = df[df['kdcode'] == stock_i]
    if stock_i_data.shape[0] > 200:
        df_ = pd.concat([df_, stock_i_data])

df_
# Out:
# 100%|██████████| 4315/4315 [1:00:58<00:00,  1.18it/s]
#                  dt     kdcode     volume      turnover    turn  pct_chg  \
# 2588     2016-01-04  000004.SZ  2283380.0  9.767487e+07  2.7223 -10.0000
# 2589     2016-01-05  000004.SZ  3883664.0  1.505349e+08  4.6303  -6.3665
# 2590     2016-01-06  000004.SZ  2114757.0  8.257999e+07  2.5213   1.2927
# 2591     2016-01-07  000004.SZ   456900.0  1.651672e+07  0.5447 -10.0051
# 2592     2016-01-08  000004.SZ  3077465.0  1.071972e+08  3.6691   0.6239
# ...             ...        ...        ...           ...     ...      ...
# 4574780  2021-07-26  688600.SH   395800.0  6.140806e+06  0.5900  -0.3800
# 4574781  2021-07-27  688600.SH   686800.0  1.094838e+07  1.0300   1.6000
# 4574782  2021-07-28  688600.SH   502000.0  7.746032e+06  0.7500  -3.1600
# 4574783  2021-07-29  688600.SH   436700.0  6.807372e+06  0.6500   1.5000
# 4574784  2021-07-30  688600.SH   330300.0  5.124066e+06  0.4900  -0.1300
#
#               vwap trade_status   adj_close    adj_open    adj_high  \
# 2588     42.776439            0  243.215104  270.239004  274.360296
# 2589     38.761049            0  227.730821  220.783500  240.742328
# 2590     39.049400            0  230.674601  227.259816  235.502400
# 2591     36.149518            0  207.595366  226.671060  226.671060
# 2592     34.832959            0  208.890629  206.829983  214.895940
# ...            ...          ...         ...         ...         ...
# 4574780  15.514923            0   15.590000   15.530000   15.680000
# 4574781  15.941140            0   15.840000   15.640000   16.170000
# 4574782  15.430343            0   15.340000   15.800000   15.860000
# 4574783  15.588212            0   15.570000   15.510000   15.790000
# 4574784  15.513369            0   15.550000   15.440000   15.600000
#
#             adj_low
# 2588     243.215104
# 2589     218.899481
# 2590     223.727280
# 2591     207.595366
# 2592     186.812279
# ...             ...
# 4574780   15.400000
# 4574781   15.590000
# 4574782   15.150000
# 4574783   15.430000
# 4574784   15.440000
#
# [4122511 rows x 12 columns]

# %%
stocks_code = df_['kdcode'].unique()
stocks_num = len(stocks_code)
"去除后的股票数量",stocks_num
# Out:
# ('去除后的股票数量', 3821)

# %%
# 按照kdcode,dt排序
df_.sort_values(by=['kdcode', 'dt'],axis=0,ascending=True,inplace=True)
df_
# Out:
#                  dt     kdcode     volume      turnover    turn  pct_chg  \
# 2588     2016-01-04  000004.SZ  2283380.0  9.767487e+07  2.7223 -10.0000
# 2589     2016-01-05  000004.SZ  3883664.0  1.505349e+08  4.6303  -6.3665
# 2590     2016-01-06  000004.SZ  2114757.0  8.257999e+07  2.5213   1.2927
# 2591     2016-01-07  000004.SZ   456900.0  1.651672e+07  0.5447 -10.0051
# 2592     2016-01-08  000004.SZ  3077465.0  1.071972e+08  3.6691   0.6239
# ...             ...        ...        ...           ...     ...      ...
# 4574780  2021-07-26  688600.SH   395800.0  6.140806e+06  0.5900  -0.3800
# 4574781  2021-07-27  688600.SH   686800.0  1.094838e+07  1.0300   1.6000
# 4574782  2021-07-28  688600.SH   502000.0  7.746032e+06  0.7500  -3.1600
# 4574783  2021-07-29  688600.SH   436700.0  6.807372e+06  0.6500   1.5000
# 4574784  2021-07-30  688600.SH   330300.0  5.124066e+06  0.4900  -0.1300
#
#               vwap trade_status   adj_close    adj_open    adj_high  \
# 2588     42.776439            0  243.215104  270.239004  274.360296
# 2589     38.761049            0  227.730821  220.783500  240.742328
# 2590     39.049400            0  230.674601  227.259816  235.502400
# 2591     36.149518            0  207.595366  226.671060  226.671060
# 2592     34.832959            0  208.890629  206.829983  214.895940
# ...            ...          ...         ...         ...         ...
# 4574780  15.514923            0   15.590000   15.530000   15.680000
# 4574781  15.941140            0   15.840000   15.640000   16.170000
# 4574782  15.430343            0   15.340000   15.800000   15.860000
# 4574783  15.588212            0   15.570000   15.510000   15.790000
# 4574784  15.513369            0   15.550000   15.440000   15.600000
#
#             adj_low
# 2588     243.215104
# 2589     218.899481
# 2590     223.727280
# 2591     207.595366
# 2592     186.812279
# ...             ...
# 4574780   15.400000
# 4574781   15.590000
# 4574782   15.150000
# 4574783   15.430000
# 4574784   15.440000
#
# [4122511 rows x 12 columns]

# %%
# 设置dt为下标
df_.set_index(['dt'], inplace = True)
df_.index = pd.to_datetime(df_.index)
df_
# Out:
#                kdcode     volume      turnover    turn  pct_chg       vwap  \
# dt
# 2016-01-04  000004.SZ  2283380.0  9.767487e+07  2.7223 -10.0000  42.776439
# 2016-01-05  000004.SZ  3883664.0  1.505349e+08  4.6303  -6.3665  38.761049
# 2016-01-06  000004.SZ  2114757.0  8.257999e+07  2.5213   1.2927  39.049400
# 2016-01-07  000004.SZ   456900.0  1.651672e+07  0.5447 -10.0051  36.149518
# 2016-01-08  000004.SZ  3077465.0  1.071972e+08  3.6691   0.6239  34.832959
# ...               ...        ...           ...     ...      ...        ...
# 2021-07-26  688600.SH   395800.0  6.140806e+06  0.5900  -0.3800  15.514923
# 2021-07-27  688600.SH   686800.0  1.094838e+07  1.0300   1.6000  15.941140
# 2021-07-28  688600.SH   502000.0  7.746032e+06  0.7500  -3.1600  15.430343
# 2021-07-29  688600.SH   436700.0  6.807372e+06  0.6500   1.5000  15.588212
# 2021-07-30  688600.SH   330300.0  5.124066e+06  0.4900  -0.1300  15.513369
#
#            trade_status   adj_close    adj_open    adj_high     adj_low
# dt
# 2016-01-04            0  243.215104  270.239004  274.360296  243.215104
# 2016-01-05            0  227.730821  220.783500  240.742328  218.899481
# 2016-01-06            0  230.674601  227.259816  235.502400  223.727280
# 2016-01-07            0  207.595366  226.671060  226.671060  207.595366
# 2016-01-08            0  208.890629  206.829983  214.895940  186.812279
# ...                 ...         ...         ...         ...         ...
# 2021-07-26            0   15.590000   15.530000   15.680000   15.400000
# 2021-07-27            0   15.840000   15.640000   16.170000   15.590000
# 2021-07-28            0   15.340000   15.800000   15.860000   15.150000
# 2021-07-29            0   15.570000   15.510000   15.790000   15.430000
# 2021-07-30            0   15.550000   15.440000   15.600000   15.440000
#
# [4122511 rows x 11 columns]

# %%
df_.to_csv('data2.csv')

# %% [markdown]
# ## 3. 查看异常值处理后各数据的`概率密度分布图`

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data2.csv')

# %%
# 1. volume
# Draw Plot
sns.kdeplot(df['volume'], shade=True, color="g", label="volume", alpha=.7)

# Decoration
plt.title('volume probability density distribution')
plt.legend()
plt.show()

# %%
# 2. turnover
# Draw Plot
sns.kdeplot(df['turnover'], shade=True, color="b", label="turnover", alpha=.7)

# Decoration
plt.title('turnover probability density distribution')
plt.legend()
plt.show()

# %%
# 3. vwap
# Draw Plot
sns.kdeplot(df['vwap'], shade=True, color="y", label="vwap", alpha=.7)

# Decoration
plt.title('vwap probability density distribution')
plt.legend()
plt.show()

# %%
# 4. adj_open
# Draw Plot
sns.kdeplot(df['adj_open'], shade=True, color="black", label="adj_open", alpha=.7)

# Decoration
plt.title('adj_open probability density distribution')
plt.legend()
plt.show()

# %%
# 5. adj_close
# Draw Plot
sns.kdeplot(df['adj_close'], shade=True, color="purple", label="adj_close", alpha=.7)

# Decoration
plt.title('adj_close probability density distribution')
plt.legend()
plt.show()

# %%
# 6. adj_high
# Draw Plot
sns.kdeplot(df['adj_high'], shade=True, color="orange", label="adj_high", alpha=.7)

# Decoration
plt.title('adj_high probability density distribution')
plt.legend()
plt.show()

# %%
# 7. adj_low
# Draw Plot
sns.kdeplot(df['adj_low'], shade=True, color="red", label="adj_low", alpha=.7)

# Decoration
plt.title('adj_low probability density distribution')
plt.legend()
plt.show()

# %%
# 8. pct_chg
# Draw Plot
sns.kdeplot(df['pct_chg'], shade=True, color="dimgray", label="pct_chg", alpha=.7)

# Decoration
plt.title('pct_chg probability density distribution')
plt.legend()
plt.show()

# %%
# 9. turn
# Draw Plot
sns.kdeplot(df['turn'], shade=True, color="dimgray", label="turn", alpha=.7)

# Decoration
plt.title('turn probability density distribution')
plt.legend()
plt.show()
