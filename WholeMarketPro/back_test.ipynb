# %% [markdown]
# # 回测记录

# %% [markdown]
# ## model_newLabel

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model_newlabel/",
                             turnover=0.1,
                             adj=5,
                             stock_count=100,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model_newlabel/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-10 09:06:54dddd strategy_policy.py INFO  start to load prediction
# 2021-08-10 09:07:55dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-10 09:07:55dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-10 09:08:49dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-10 09:08:51dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-10 09:08:51dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-10 09:08:51dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-10 09:08:51dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# 2021-08-10 09:08:51dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-14 ..
# 2021-08-10 09:08:51dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-14 ..
# 2021-08-10 09:08:52dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-15
# ...

# %% [markdown]
# ### model_newlLabel 20个epochs：
#
# #### 0.1 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.052633	0.256802	-0.213845	0.204957	0.246129	0.329280	0.555556	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.102144	0.162596	-0.305129	-0.628207	-0.334758	-0.583209	0.444444	0
#
# 0.1 50
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.023162	0.255019	-0.239568	-0.090825	-0.096683	0.035971	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.166040	0.153620	-0.329373	-1.080843	-0.504108	-1.108018	0.444444	0
#
# 0.1 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.012028	0.252213	-0.243675	-0.047689	-0.049360	0.078634	0.555556	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.155851	0.143467	-0.336374	-1.086321	-0.463326	-1.112137	0.500000	0
#
# 0.1 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.004392	0.248960	-0.243675	0.017642	0.018025	0.142779	0.611111	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.141826	0.137788	-0.336374	-1.029302	-0.421631	-1.043928	0.500000	0
#
# 0.1 3 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.077136	0.249997	-0.210544	0.308549	0.366367	0.423817	0.555556	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.082088	0.157846	-0.269265	-0.520052	-0.304860	-0.465228	0.500000	0
#
# 0.1 3 50
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.086726	0.240818	-0.218366	0.360132	0.397159	0.467498	0.555556	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.073767	0.141760	-0.265776	-0.520364	-0.277552	-0.471257	0.555556	0
#
# 0.1 5 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.058739	0.228525	-0.197683	0.257036	0.297139	0.365394	0.555556	10
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.098772	0.129543	-0.254685	-0.762465	-0.387821	-0.740182	0.555556	0
#
# 0.1 3 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.044215	0.237613	-0.239172	0.186081	0.184867	0.302059	0.500000	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.110468	0.139774	-0.295075	-0.790336	-0.374374	-0.769916	0.555556	0

# %% [markdown]
# ## model2_newLabel

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model2_newlabel/",
                             turnover=0.1,
                             adj=3,
                             stock_count=50,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model2_newlabel/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-10 17:33:01dddd strategy_policy.py INFO  start to load prediction
# 2021-08-10 17:34:30dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-10 17:34:30dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-10 17:35:26dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-10 17:35:26dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-10 17:35:26dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-10 17:35:26dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-10 17:35:27dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# 2021-08-10 17:35:27dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-14 ..
# 2021-08-10 17:35:27dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-14 ..
# 2021-08-10 17:35:28dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-16
# ...

# %% [markdown]
# ### 10 epochs:
# 0.1 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.002257	0.261838	-0.303236	-0.008620	-0.007443	0.122940	0.500000	16
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.149486	0.173887	-0.376805	-0.859673	-0.396720	-0.846510	0.444444	0
#
# 0.1 3 50
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.034763	0.252995	-0.237313	0.137406	0.146486	0.262651	0.611111	16
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.117271	0.155658	-0.312316	-0.753388	-0.375488	-0.725552	0.388889	0
#
# 0.1 3 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.065137	0.218475	-0.176054	0.298143	0.369983	0.399564	0.555556	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.094173	0.118915	-0.223099	-0.791940	-0.422114	-0.774440	0.555556	0
#
# 0.1 5 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.079219	0.226539	-0.235813	0.349695	0.335942	0.451380	0.611111	10
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.081758	0.129564	-0.278179	-0.631025	-0.293904	-0.595324	0.555556	0
#
# 0.1 3 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.057571	0.224281	-0.226679	0.256693	0.253976	0.363005	0.555556	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.099205	0.116380	-0.261373	-0.852427	-0.379555	-0.841830	0.555556	0
#
# 0.1 5 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.062578	0.246974	-0.225479	0.253379	0.277534	0.370893	0.611111	9
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.092280	0.136212	-0.272097	-0.677475	-0.339144	-0.644485	0.611111	0

# %% [markdown]
# ### 20 epochs:
# 0.1 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.022404	0.244632	-0.198720	0.091584	0.112744	0.213864	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.127720	0.141035	-0.296213	-0.905595	-0.431178	-0.900979	0.500000	0
#
# 0.1 100
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.036598	0.244885	-0.198720	0.149451	0.184171	0.270361	0.555556	49
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.115594	0.141405	-0.296213	-0.817466	-0.390239	-0.800396	0.555556	0
#
# 0.1 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.010867	0.248304	-0.244702	0.043764	0.044408	0.168580	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.137039	0.143095	-0.318788	-0.957677	-0.429874	-0.961098	0.611111	0
#
# ### 30 epochs
# 0.1 30
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.081251	0.260266	-0.273506	-0.312186	-0.297073	-0.195773	0.555556	49
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.215254	0.158846	-0.358875	-1.355110	-0.599801	-1.450085	0.500000	0
#
# 0.1 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.007668	0.248585	-0.244702	0.030846	0.031336	0.155887	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.139802	0.143827	-0.318788	-0.972016	-0.438543	-0.977814	0.611111	0
#
# 0.1 3 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.049603	0.241997	-0.230510	0.204973	0.215188	0.322289	0.555556	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.106031	0.148224	-0.240353	-0.715342	-0.441148	-0.684059	0.500000	0
#
# 0.1 3 60
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.077693	0.239208	-0.210796	0.324794	0.368571	0.433988	0.611111	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.081934	0.142498	-0.258825	-0.574983	-0.316561	-0.530351	0.611111	0
#
# 0.1 3 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.024187	0.237016	-0.232355	0.102047	0.104094	0.220312	0.555556	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.127650	0.139618	-0.281146	-0.914280	-0.454033	-0.910842	0.555556	0
#
# 0.1 3 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	**0.147874**	0.224413	-0.189692	0.658938	0.779549	0.729383	0.666667	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.021829	0.113420	-0.193283	-0.192462	-0.112938	-0.138459	0.611111	0

# %% [markdown]
# ## model2_1

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model2_1/",
                             turnover=0.1,
                             adj=1,
                             stock_count=300,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model2_1/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-08 15:21:26dddd strategy_policy.py INFO  start to load prediction
# 2021-08-08 15:26:36dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-08 15:26:36dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-08 15:27:33dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-08 15:27:34dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002277.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-08 15:27:34dddd utils.py INFO  [Step 1] 有交易信号,kdcode=601010.SH,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-08 15:27:34dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002656.SZ,dt=2020-01-10,trade_type=1,股票停牌！
# 2021-08-08 15:27:56dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600354.SH,dt=2020-01-21,trade_type=-1.0,股票跌停！
# 2021-08-08 15:28:00dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600354.SH,dt=2020-01-22,trade_type=-1.0,股票跌停！
# ...

# %% [markdown]
# 0.1 30
# portfolio_net_value	-0.154273	0.250851	-0.380492	-0.615001	-0.405458	-0.542925	0.444444	49
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.278475	0.151465	-0.470442	-1.838545	-0.591942	-2.083524	0.333333	0
#
# 0.1 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.072912	0.236344	-0.259713	-0.308501	-0.280742	-0.201932	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.210754	0.142118	-0.368141	-1.482952	-0.572482	-1.598058	0.333333	0
#
# 0.1 300
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.006866	0.228473	-0.213619	0.030050	0.032140	0.145202	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.142833	0.128737	-0.293830	-1.109501	-0.486109	-1.135749	0.500000	0

# %% [markdown]
# ## model2_2

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model2_2/",
                             turnover=0.1,
                             adj=5,
                             stock_count=70,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model2_2/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-10 10:20:04dddd strategy_policy.py INFO  start to load prediction
# 2021-08-10 10:21:04dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-10 10:21:04dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-10 10:21:58dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-10 10:21:59dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-10 10:21:59dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-10 10:21:59dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# 2021-08-10 10:22:00dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-14
# 2021-08-10 10:22:00dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-14 ..
# 2021-08-10 10:22:00dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-14 ..
# 2021-08-10 10:22:00dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-15
# ...

# %% [markdown]
# #### 0.1 3 60
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.079816	0.218437	-0.175278	0.365397	0.455369	0.462656	0.611111	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.080824	0.111062	-0.203564	-0.727734	-0.397044	-0.705248	0.500000	0
#
# 0.05 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.105412	0.220658	-0.175374	0.477715	0.601068	0.566570	0.611111	25
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.060390	0.127254	-0.208152	-0.474566	-0.290126	-0.427250	0.611111	0
#
# 0.05 0.5 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.105412	0.220658	-0.175374	0.477715	0.601068	0.566570	0.611111	25
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.060390	0.127254	-0.208152	-0.474566	-0.290126	-0.427250	0.611111	0
#
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.129218	0.248285	-0.216114	0.520442	0.597915	0.615766	0.555556	9
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.038097	0.158037	-0.244732	-0.241065	-0.155669	-0.167694	0.611111	0
#
# 0.1 5 100
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.128103	0.238237	-0.218873	0.537714	0.585285	0.627335	0.500000	10
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.042487	0.165165	-0.221718	-0.257240	-0.191627	-0.181231	0.444444	0
#
# 0.1 3 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.141906	0.239782	-0.190372	0.591813	0.745414	0.675760	0.611111	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.029958	0.162506	-0.230956	-0.184352	-0.129715	-0.106779	0.555556	0
#
# 0.1 5 500
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.119695	0.223454	-0.203682	0.535659	0.587656	0.619871	0.555556	10
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.047956	0.129663	-0.204039	-0.369854	-0.235036	-0.315238	0.500000	0

# %% [markdown]
# ## model3_1

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model3_1/",
                             turnover=0.1,
                             adj=1,
                             stock_count=30,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model3_1/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-08 11:28:55dddd strategy_policy.py INFO  start to load prediction
# 2021-08-08 11:33:25dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-08 11:33:25dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-08 11:34:20dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-08 11:34:25dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600255.SH,dt=2020-01-23,trade_type=-1,股票跌停！
# 2021-08-08 11:34:26dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600255.SH,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-08-08 11:34:26dddd utils.py INFO  [Step 1] 有交易信号,kdcode=300071.SZ,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-08-08 11:34:26dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000716.SZ,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-08-08 11:34:26dddd utils.py INFO  [Step 1] 有交易信号,kdcode=300173.SZ,dt=2020-02-03,trade_type=-1,股票跌停！
# ...

# %% [markdown]
# ## model4

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model4/",
                             turnover=0.1,
                             adj=1,
                             stock_count=100,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model4/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-08 11:37:57dddd strategy_policy.py INFO  start to load prediction
# 2021-08-08 11:42:32dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-08 11:42:32dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-08 11:43:26dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-08 11:43:31dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600226.SH,dt=2020-01-16,trade_type=1.0,股票停牌！
# 2021-08-08 11:43:35dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600354.SH,dt=2020-01-21,trade_type=-1,股票跌停！
# 2021-08-08 11:43:36dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600354.SH,dt=2020-01-22,trade_type=-1,股票跌停！
# 2021-08-08 11:43:37dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600354.SH,dt=2020-01-23,trade_type=-1,股票跌停！
# 2021-08-08 11:43:38dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600354.SH,dt=2020-02-03,trade_type=-1,股票跌停！
# ...

# %% [markdown]
# 0.1 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.056050	0.253308	-0.282396	-0.221273	-0.198481	-0.100795	0.444444	49
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.196922	0.172794	-0.382681	-1.139633	-0.514584	-1.185918	0.333333	0
#
# 0.1 50
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.057001	0.250107	-0.285124	-0.227905	-0.199915	-0.109530	0.555556	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.196934	0.161680	-0.389322	-1.218046	-0.505838	-1.278952	0.333333	0
#
# 0.1 100
# portfolio_net_value	-0.034203	0.244826	-0.257180	-0.139705	-0.132994	-0.019441	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.177247	0.151264	-0.360396	-1.171775	-0.491811	-1.217392	0.500000	0

# %% [markdown]
# ## model4_1

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model4_1/",
                             turnover=0.1,
                             adj=1,
                             stock_count=50,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model4_1/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-08 11:51:30dddd strategy_policy.py INFO  start to load prediction
# 2021-08-08 11:55:58dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-08 11:55:58dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-08 11:56:54dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-08 11:56:57dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600226.SH,dt=2020-01-16,trade_type=-1,股票停牌！
# 2021-08-08 11:56:57dddd utils.py INFO  [Step 2] kdcode=600226.SH,dt=2020-01-16,今日股票停牌！
# 2021-08-08 11:56:57dddd utils.py INFO  [Step 3] kdcode=600226.SH,dt=2020-01-16,今日股票停牌！
# 2021-08-08 11:56:57dddd utils.py INFO  [Step 1] kdcode=600226.SH,dt=2020-01-17,股票停牌！
# 2021-08-08 11:56:58dddd utils.py INFO  [Step 2] kdcode=600226.SH,dt=2020-01-17,今日股票停牌！
# 2021-08-08 11:56:58dddd utils.py INFO  [Step 3] kdcode=600226.SH,dt=2020-01-17,今日股票停牌！
# ...

# %% [markdown]
# 0.1 30
# portfolio_net_value	-0.068524	0.260818	-0.296078	-0.262729	-0.231440	-0.141426	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.203035	0.149491	-0.335435	-1.358179	-0.605288	-1.446737	0.444444	0
#
# 0.1 50
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	-0.050174	0.253023	-0.259549	-0.198296	-0.193311	-0.076330	0.500000	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.188103	0.142519	-0.332380	-1.319846	-0.565926	-1.394209	0.333333	0

# %% [markdown]
# ## model5

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model5/",
                             turnover=0.1,
                             adj=3,
                             stock_count=500,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model5/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-10 15:10:29dddd strategy_policy.py INFO  start to load prediction
# 2021-08-10 15:17:36dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-10 15:17:36dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-10 15:19:27dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-10 15:19:28dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002277.SZ,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-10 15:19:28dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002656.SZ,dt=2020-01-10,trade_type=1,股票停牌！
# 2021-08-10 15:19:29dddd utils.py INFO  [Step 1] 有交易信号,kdcode=601010.SH,dt=2020-01-10,trade_type=1,股票涨停！
# 2021-08-10 15:19:33dddd utils.py INFO  [Step 1] 当前无交易信号,dt=2020-01-13
# 2021-08-10 15:19:33dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-13 ..
# 2021-08-10 15:19:33dddd utils.py WARNING  no data in df_res_trade_signal on 2020-01-13 ..
# ...

# %% [markdown]
# 0.1 30
# portfolio_net_value	-0.068512	0.258051	-0.228981	-0.265499	-0.299206	-0.145832	0.500000	49
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.204014	0.152821	-0.309127	-1.334986	-0.659969	-1.420085	0.388889	0
#
# 0.1 50
# portfolio_net_value	-0.073801	0.255191	-0.255721	-0.289201	-0.288602	-0.172641	0.555556	49
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.208170	0.144820	-0.352676	-1.437437	-0.590259	-1.542903	0.444444	0
#
# 0.1 500
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.034696	0.227797	-0.208485	0.152313	0.166422	0.264978	0.611111	50
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.117260	0.109547	-0.230308	-1.070416	-0.509146	-1.086534	0.500000	0

# %% [markdown]
# 0.1 3 30
# 年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.033582	0.259122	-0.282006	0.129598	0.119081	0.258435	0.666667	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.116423	0.152678	-0.362026	-0.762538	-0.321588	-0.736327	0.666667	0
#
# 0.1 3 100
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.050499	0.241247	-0.227831	0.209326	0.221652	0.326416	0.611111	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.102611	0.125619	-0.269159	-0.816841	-0.381228	-0.801155	0.500000	0
#
# 0.1 3 500
# 	年化收益	年化波动率	最大回撤率	夏普率	Calmar	IR	月度胜率	双边换手率
# portfolio_net_value	0.096129	0.226472	-0.194115	0.424463	0.495217	0.520607	0.611111	17
# 000905.SH_net_value	0.165463	0.226113	-0.152400	0.731771	1.085717	0.793351	0.722222	0
# alpha_net_value	-0.064553	0.104057	-0.194370	-0.620362	-0.332114	-0.590870	0.611111	0

# %% [markdown]
# ## model5_1

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210806_tiho",
                             model_root_dir="./result4tiho/model5_1/",
                             turnover=0.1,
                             adj=3,
                             stock_count=750,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("./result4tiho/model5_1/20210806_tiho/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-10 13:40:51dddd strategy_policy.py INFO  start to load prediction
# 2021-08-10 13:42:58dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-10 13:42:58dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-20
# 2021-08-10 13:43:53dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-10 13:43:54dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002277.SZ,dt=2020-01-10,trade_type=1,股票涨停！
