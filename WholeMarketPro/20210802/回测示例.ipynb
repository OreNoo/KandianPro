# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy
stock_pool = "hs300" 
strategy_policy = StrategyPolicy(start_date=None,
                                 end_date=None,
                                 strategy_name="20210801_hs",
                                 model_root_dir="/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result/",
                                 turnover=0.1,
                                 adj=1,
                                 stock_count=30,
                                 # stock_universe_conf = stock_pool,
                                 reference_index = "000300.SH" 
                                 )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result/20210801_hs/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/tianhao/env4tiho_py36/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 2021-08-05 16:26:18dddd strategy_policy.py INFO  start to load prediction
# 2021-08-05 16:27:41dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-05 16:27:41dddd strategy_policy.py INFO  Start Date : 2020-01-02, End Date 2020-12-31
# 2021-08-05 16:28:28dddd utils.py WARNING  df_cur_position is None on 2020-01-02, skipping update_close_position_mkt_value ..
# 2021-08-05 16:28:36dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002311.SZ,dt=2020-02-03,trade_type=-1.0,股票跌停！
# 2021-08-05 16:28:36dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600369.SH,dt=2020-02-03,trade_type=-1.0,股票跌停！
# 2021-08-05 16:28:48dddd utils.py INFO  [Step 1] 有交易信号,kdcode=300070.SZ,dt=2020-03-06,trade_type=0,股票停牌！
# 2021-08-05 16:28:48dddd utils.py INFO  [Step 2] kdcode=300070.SZ,dt=2020-03-06,今日股票停牌！
# 2021-08-05 16:28:48dddd utils.py INFO  [Step 3] kdcode=300070.SZ,dt=2020-03-06,今日股票停牌！
# 2021-08-05 16:28:49dddd utils.py INFO  [Step 1] kdcode=300070.SZ,dt=2020-03-09,股票停牌！
# 2021-08-05 16:28:49dddd utils.py INFO  [Step 2] kdcode=300070.SZ,dt=2020-03-09,今日股票停牌！
# 2021-08-05 16:28:49dddd utils.py INFO  [Step 3] kdcode=300070.SZ,dt=2020-03-09,今日股票停牌！
# 2021-08-05 16:28:49dddd utils.py INFO  [Step 1] kdcode=300070.SZ,dt=2020-03-10,股票停牌！
# 2021-08-05 16:28:49dddd utils.py INFO  [Step 2] kdcode=300070.SZ,dt=2020-03-10,今日股票停牌！
# 2021-08-05 16:28:49dddd utils.py INFO  [Step 3] kdcode=300070.SZ,dt=2020-03-10,今日股票停牌！
# 2021-08-05 16:28:50dddd utils.py INFO  [Step 1] kdcode=300070.SZ,dt=2020-03-11,股票停牌！
# 2021-08-05 16:28:50dddd utils.py INFO  [Step 2] kdcode=300070.SZ,dt=2020-03-11,今日股票停牌！
# 2021-08-05 16:28:50dddd utils.py INFO  [Step 3] kdcode=300070.SZ,dt=2020-03-11,今日股票停牌！
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8e9c2bce5123> in <module>
#      29                                  )
#      30 strategy_policy.balance_position()
# ---> 31 strategy_policy.cal_strategy_performance()
#      32 strategy_policy.strategy_performance_statistic()
#      33 df = pd.read_csv("/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result/20210801_hs/performance/alpha_statistics_df.csv",index_col=0)
#
# ~/env4tiho_py36/lib/python3.6/site-packages/kd_backtest/strategy/strategy_policy.py in cal_strategy_performance(self, df_quote)
#     960                                                df_prev_position,
#     961                                                df_prev_performance,
# --> 962                                                simulation_config)
#     963             filename = str(cur_date.date()) + ".csv"
#     964
#
# ~/env4tiho_py36/lib/python3.6/site-packages/kd_backtest/simulation/utils.py in simulation(start_dt, end_dt, df_model_signal, df_quote, df_prev_trade_signal, df_prev_position, df_prev_performance, simulation_config)
#    1139         df_cur_quote = grouped_df_quote.get_group(dt)
#    1140         df_cur_trade_transaction, df_cur_position, df_cur_performance, updated_trade_signal = simulate_trade_transaction(
# -> 1141             dt, df_prev_trade_signal, df_prev_position, df_prev_performance, df_cur_quote, simulation_config)
#    1142         # 不保存更新的signal，在transaction里面可以看到交易情况
#    1143         # if updated_trade_signal is not None and len(updated_trade_signal) != 0:
#
# ~/env4tiho_py36/lib/python3.6/site-packages/kd_backtest/simulation/utils.py in simulate_trade_transaction(trade_dt, df_prev_trade_signal, df_prev_position, df_prev_performance, df_cur_quote, simulation_config, stock_eps)
#     473             # 更新交易信号表的 交易价格、后复权因子
#     474
# --> 475             strategy_trade_signal_df.loc[index, "trade_price"] = trade_price
#     476             strategy_trade_signal_df.loc[index, "trade_adj_factor"] = adj_factor
#     477             if trade_type == 0:
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     555                 # scalar
#     556                 for item in labels:
# --> 557                     setter(item, value)
#     558
#     559         else:
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/indexing.py in setter(item, v)
#     487                     # set the item, possibly having a dtype change
#     488                     s._consolidate_inplace()
# --> 489                     s = s.copy()
#     490                     s._data = s._data.setitem(indexer=pi, value=v)
#     491                     s._maybe_update_cacher(clear=True)
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    5994         dtype: object
#    5995         """
# -> 5996         data = self._data.copy(deep=deep)
#    5997         return self._constructor(data).__finalize__(self)
#    5998
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in copy(self, deep)
#     786         else:
#     787             new_axes = list(self.axes)
# --> 788         return self.apply("copy", axes=new_axes, deep=deep, do_integrity_check=False)
#     789
#     790     def as_array(self, transpose=False, items=None):
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in copy(self, deep)
#     770         if deep:
#     771             values = values.copy()
# --> 772         return self.make_block_same_class(values, ndim=self.ndim)
#     773
#     774     def replace(
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block_same_class(self, values, placement, ndim, dtype)
#     278             ndim = self.ndim
#     279         return make_block(
# --> 280             values, placement=placement, ndim=ndim, klass=self.__class__, dtype=dtype
#     281         )
#     282
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3282         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3283
# -> 3284     return klass(values, ndim=ndim, placement=placement)
#    3285
#    3286
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     119
#     120     def __init__(self, values, placement, ndim=None):
# --> 121         self.ndim = self._check_ndim(values, ndim)
#     122         self.mgr_locs = placement
#     123         self.values = values
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _check_ndim(self, values, ndim)
#     153             ndim = values.ndim
#     154
# --> 155         if self._validate_ndim and values.ndim != ndim:
#     156             msg = "Wrong number of dimensions. values.ndim != ndim [{} != {}]"
#     157             raise ValueError(msg.format(values.ndim, ndim))
#
# KeyboardInterrupt:

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy
stock_pool = "zz500"
strategy_policy = StrategyPolicy(start_date=None,
                                 end_date=None,
                                 strategy_name="20210801_zz",
                                 model_root_dir="/home/zhupeng/20210801/result/",
                                 turnover=0.1,
                                 adj=1,
                                 stock_count=30,
                                 stock_universe_conf = stock_pool,
                                 reference_index = "000905.SH" 
                                 )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("/home/zhupeng/20210801/result/20210801_zz/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-07-31 23:21:23dddd strategy_policy.py INFO  start to load prediction
# 2021-07-31 23:22:42dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-07-31 23:22:42dddd strategy_policy.py INFO  Start Date : 2020-01-02, End Date 2020-12-31
# 2021-07-31 23:23:32dddd utils.py WARNING  df_cur_position is None on 2020-01-02, skipping update_close_position_mkt_value ..
# 2021-07-31 23:23:41dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600835.SH,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-07-31 23:23:41dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600639.SH,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-07-31 23:23:41dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002701.SZ,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-07-31 23:24:09dddd utils.py INFO  [Step 1] 有交易信号,kdcode=300197.SZ,dt=2020-04-13,trade_type=0,股票停牌！
# 2021-07-31 23:24:09dddd utils.py INFO  [Step 2] kdcode=300197.SZ,dt=2020-04-13,今日股票停牌！
# 2021-07-31 23:24:09dddd utils.py INFO  [Step 3] kdcode=300197.SZ,dt=2020-04-13,今日股票停牌！
# 2021-07-31 23:24:10dddd utils.py INFO  [Step 1] kdcode=300197.SZ,dt=2020-04-14,股票停牌！
# 2021-07-31 23:24:10dddd utils.py INFO  [Step 2] kdcode=300197.SZ,dt=2020-04-14,今日股票停牌！
# 2021-07-31 23:24:10dddd utils.py INFO  [Step 3] kdcode=300197.SZ,dt=2020-04-14,今日股票停牌！
# 2021-07-31 23:24:10dddd utils.py INFO  [Step 1] kdcode=300197.SZ,dt=2020-04-15,股票停牌！
# 2021-07-31 23:24:10dddd utils.py INFO  [Step 2] kdcode=300197.SZ,dt=2020-04-15,今日股票停牌！
# 2021-07-31 23:24:10dddd utils.py INFO  [Step 3] kdcode=300197.SZ,dt=2020-04-15,今日股票停牌！
# 2021-07-31 23:24:11dddd utils.py INFO  [Step 1] kdcode=300197.SZ,dt=2020-04-16,股票停牌！
# 2021-07-31 23:24:11dddd utils.py INFO  [Step 2] kdcode=300197.SZ,dt=2020-04-16,今日股票停牌！
# 2021-07-31 23:24:11dddd utils.py INFO  [Step 3] kdcode=300197.SZ,dt=2020-04-16,今日股票停牌！
# 2021-07-31 23:24:11dddd utils.py INFO  [Step 1] kdcode=300197.SZ,dt=2020-04-17,股票停牌！
# 2021-07-31 23:24:12dddd utils.py INFO  [Step 2] kdcode=300197.SZ,dt=2020-04-17,今日股票停牌！
# 2021-07-31 23:24:12dddd utils.py INFO  [Step 3] kdcode=300197.SZ,dt=2020-04-17,今日股票停牌！
# 2021-07-31 23:24:52dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002625.SZ,dt=2020-08-06,trade_type=1,股票涨停！
# 2021-07-31 23:25:33dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002075.SZ,dt=2020-11-19,trade_type=0,股票停牌！
# 2021-07-31 23:25:33dddd utils.py INFO  [Step 2] kdcode=002075.SZ,dt=2020-11-19,今日股票停牌！
# 2021-07-31 23:25:33dddd utils.py INFO  [Step 3] kdcode=002075.SZ,dt=2020-11-19,今日股票停牌！
# 2021-07-31 23:25:33dddd utils.py INFO  [Step 1] kdcode=002075.SZ,dt=2020-11-20,股票停牌！
# 2021-07-31 23:25:34dddd utils.py INFO  [Step 2] kdcode=002075.SZ,dt=2020-11-20,今日股票停牌！
# 2021-07-31 23:25:34dddd utils.py INFO  [Step 3] kdcode=002075.SZ,dt=2020-11-20,今日股票停牌！
# 2021-07-31 23:25:34dddd utils.py INFO  [Step 1] kdcode=002075.SZ,dt=2020-11-23,股票停牌！
# 2021-07-31 23:25:34dddd utils.py INFO  [Step 2] kdcode=002075.SZ,dt=2020-11-23,今日股票停牌！
# 2021-07-31 23:25:34dddd utils.py INFO  [Step 3] kdcode=002075.SZ,dt=2020-11-23,今日股票停牌！
# 2021-07-31 23:25:34dddd utils.py INFO  [Step 1] kdcode=002075.SZ,dt=2020-11-24,股票停牌！
# 2021-07-31 23:25:35dddd utils.py INFO  [Step 2] kdcode=002075.SZ,dt=2020-11-24,今日股票停牌！
# 2021-07-31 23:25:35dddd utils.py INFO  [Step 3] kdcode=002075.SZ,dt=2020-11-24,今日股票停牌！
#                          年化收益     年化波动率     最大回撤率       夏普率    Calmar  \
# portfolio_net_value  0.174677  0.295568 -0.186278  0.590988  0.937721
# 000905.SH_net_value  0.191797  0.256224 -0.152400  0.748552  1.258511
# alpha_net_value     -0.007307  0.087461 -0.096329 -0.083551 -0.075859
#
#                            IR      月度胜率  双边换手率
# portfolio_net_value  0.696624  0.545455     49
# 000905.SH_net_value  0.817416  0.727273      0
# alpha_net_value     -0.040500  0.545455      0

# %%
import os
os.environ["kdconfig"] = "database.yaml"
os.environ["dbsync_config"] = "sync_config.ini"
from kd_backtest.api import *
import warnings
warnings.filterwarnings('ignore')


import matplotlib
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif' #解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False


import datetime
import pandas as pd
from kd_backtest.strategy import strategy_policy

strategy_policy = StrategyPolicy(start_date=None,
                             end_date=None,
                             strategy_name="20210802_tiho1",
                             model_root_dir="/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result4tiho/",
                             turnover=0.1,
                             adj=1,
                             stock_count=30,
                             )
strategy_policy.balance_position()
strategy_policy.cal_strategy_performance()
strategy_policy.strategy_performance_statistic()
df = pd.read_csv("/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result4tiho/20210802_tiho1/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
# 2021-08-05 16:38:15dddd strategy_policy.py INFO  start to load prediction
# 2021-08-05 16:43:41dddd strategy_policy.py INFO  receiving data df_market_quote from DB ..
# 2021-08-05 16:43:41dddd strategy_policy.py INFO  Start Date : 2020-01-09, End Date 2021-07-19
# 2021-08-05 16:44:47dddd utils.py WARNING  df_cur_position is None on 2020-01-09, skipping update_close_position_mkt_value ..
# 2021-08-05 16:44:49dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-01-15 ..
# 2021-08-05 16:44:53dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002526.SZ,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-08-05 16:44:53dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600255.SH,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-08-05 16:44:53dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000420.SZ,dt=2020-02-03,trade_type=-1,股票跌停！
# 2021-08-05 16:44:54dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600255.SH,dt=2020-02-04,trade_type=-1,股票跌停！
# 2021-08-05 16:45:01dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-02-20 ..
# 2021-08-05 16:45:02dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-02-24 ..
# 2021-08-05 16:45:03dddd utils.py WARNING  no data in df_cur_trade_transaction on 2020-02-26 ..
# 2021-08-05 16:45:07dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002305.SZ,dt=2020-03-09,trade_type=-1,股票跌停！
# 2021-08-05 16:45:08dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002305.SZ,dt=2020-03-10,trade_type=-1,股票跌停！
# 2021-08-05 16:45:09dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600555.SH,dt=2020-03-12,trade_type=1,股票涨停！
# 2021-08-05 16:45:20dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002247.SZ,dt=2020-04-13,trade_type=-1.0,股票跌停！
# 2021-08-05 16:45:22dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000727.SZ,dt=2020-04-15,trade_type=0,股票停牌！
# 2021-08-05 16:45:22dddd utils.py INFO  [Step 2] kdcode=000727.SZ,dt=2020-04-15,今日股票停牌！
# 2021-08-05 16:45:22dddd utils.py INFO  [Step 3] kdcode=000727.SZ,dt=2020-04-15,今日股票停牌！
# 2021-08-05 16:45:23dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000727.SZ,dt=2020-04-17,trade_type=-1,股票跌停！
# 2021-08-05 16:45:23dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000727.SZ,dt=2020-04-20,trade_type=-1.0,股票跌停！
# 2021-08-05 16:45:24dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000727.SZ,dt=2020-04-21,trade_type=-1,股票跌停！
# 2021-08-05 16:45:24dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000727.SZ,dt=2020-04-22,trade_type=-1.0,股票跌停！
# 2021-08-05 16:45:25dddd utils.py INFO  [Step 1] kdcode=600225.SH,dt=2020-04-23,股票停牌！
# 2021-08-05 16:45:26dddd utils.py INFO  [Step 1] kdcode=002256.SZ,dt=2020-04-24,股票停牌！
# 2021-08-05 16:45:27dddd utils.py INFO  [Step 1] 有交易信号,kdcode=000536.SZ,dt=2020-04-28,trade_type=0,股票停牌！
# 2021-08-05 16:45:27dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600255.SH,dt=2020-04-28,trade_type=1,股票涨停！
# 2021-08-05 16:45:27dddd utils.py INFO  [Step 2] kdcode=000536.SZ,dt=2020-04-28,今日股票停牌！
# 2021-08-05 16:45:27dddd utils.py INFO  [Step 3] kdcode=000536.SZ,dt=2020-04-28,今日股票停牌！
# 2021-08-05 16:45:27dddd utils.py INFO  [Step 1] 有交易信号,kdcode=
ddd utils.py INFO  [Step 1] 有交易信号,kdcode=002504.SZ,dt=2021-04-28,trade_type=-1,股票跌停！
# 2021-08-05 16:47:56dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002504.SZ,dt=2021-04-29,trade_type=-1,股票跌停！
# 2021-08-05 16:47:57dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002619.SZ,dt=2021-04-29,trade_type=0,股票停牌！
# 2021-08-05 16:47:57dddd utils.py INFO  [Step 2] kdcode=002619.SZ,dt=2021-04-29,今日股票停牌！
# 2021-08-05 16:47:57dddd utils.py INFO  [Step 3] kdcode=002619.SZ,dt=2021-04-29,今日股票停牌！
# 2021-08-05 16:47:57dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600393.SH,dt=2021-04-30,trade_type=0.0,股票停牌！
# 2021-08-05 16:47:58dddd utils.py INFO  [Step 2] kdcode=600393.SH,dt=2021-04-30,今日股票停牌！
# 2021-08-05 16:47:58dddd utils.py INFO  [Step 3] kdcode=600393.SH,dt=2021-04-30,今日股票停牌！
# 2021-08-05 16:47:58dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002619.SZ,dt=2021-05-06,trade_type=-1,股票跌停！
# 2021-08-05 16:47:59dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600393.SH,dt=2021-05-07,trade_type=-1,股票跌停！
# 2021-08-05 16:47:59dddd utils.py INFO  [Step 1] 有交易信号,kdcode=002619.SZ,dt=2021-05-07,trade_type=-1,股票跌停！
# 2021-08-05 16:47:59dddd utils.py WARNING  no data in df_cur_trade_transaction on 2021-05-07 ..
# 2021-08-05 16:47:59dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600393.SH,dt=2021-05-10,trade_type=-1,股票跌停！
# 2021-08-05 16:48:00dddd utils.py INFO  [Step 1] 有交易信号,kdcode=600393.SH,dt=2021-05-11,trade_type=-1.0,股票跌停！
# 2021-08-05 16:48:24dddd utils.py WARNING  no data in df_cur_trade_transaction on 2021-07-02 ..
# 2021-08-05 16:48:28dddd utils.py WARNING  no data in df_cur_trade_transaction on 2021-07-13 ..
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-44d0a0902b38> in <module>
#      29 strategy_policy.cal_strategy_performance()
#      30 strategy_policy.strategy_performance_statistic()
# ---> 31 df = pd.read_csv("/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result4tiho/20210801_hs/performance/alpha_statistics_df.csv",index_col=0)
#      32 df
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/env4tiho_py36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result4tiho/20210801_hs/performance/alpha_statistics_df.csv' does not exist: b'/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result4tiho/20210801_hs/performance/alpha_statistics_df.csv'

# %%
df = pd.read_csv("/home/tianhao/TihoProFile/KandianPro/WholeMarketPro/20210802/result4tiho/20210802_tiho1/performance/alpha_statistics_df.csv",index_col=0)
df
# Out:
#                          年化收益     年化波动率     最大回撤率       夏普率    Calmar  \
# portfolio_net_value  0.150024  0.240245 -0.210747  0.624463  0.711871
# 000905.SH_net_value  0.164586  0.226419 -0.152400  0.726908  1.079960
# alpha_net_value     -0.026604  0.187807 -0.260943 -0.141655 -0.101953
#
#                            IR      月度胜率  双边换手率
# portfolio_net_value  0.704267  0.500000     32
# 000905.SH_net_value  0.789256  0.722222      0
# alpha_net_value     -0.050614  0.444444      0

# %% [markdown]
# ---

# %% [markdown]
# 1. 添加其他股票特征
#        1.1 顺势指标CCI
#        1.2 强力指数FI
