# %% [markdown]
# ## 0. 实验介绍
# 使用
# ```
# -adj_close: 收盘价
# -close_mean5: 5日收盘均价
# -close_mean10: 10日收盘均价
# -close_mean20: 20日收盘均价
# ```
# **四个数据属性**基于**GRU**模型预测未来一个交易日的涨跌。

# %% [markdown]
# ## 1. 数据预处理
# ### 1.1 根据股票代码划分数据
# * 训练集

# %%
import pandas as pd

df = pd.read_csv("./data/train.csv", usecols=[0,1,10,11,12,13])
stocks_code = df["kdcode"].unique()
stock_num = len(stocks_code)

print(stocks_code)
stock_num
# Out:
# ['000001.SZ' '000157.SZ' '000333.SZ' '000568.SZ' '000703.SZ' '000768.SZ'
#  '002024.SZ' '002044.SZ' '002049.SZ' '002120.SZ' '002230.SZ' '002271.SZ'
#  '002311.SZ' '002371.SZ' '002456.SZ' '002602.SZ' '002607.SZ' '002714.SZ'
#  '002773.SZ' '300003.SZ' '300033.SZ' '300124.SZ' '300144.SZ' '300628.SZ'
#  '600000.SH' '600009.SH' '600016.SH' '600019.SH' '600025.SH' '600028.SH'
#  '600030.SH' '600031.SH' '600036.SH' '600048.SH' '600050.SH' '600061.SH'
#  '600104.SH' '600115.SH' '600196.SH' '600276.SH' '600309.SH' '600340.SH'
#  '600383.SH' '600489.SH' '600519.SH' '600547.SH' '600570.SH' '600585.SH'
#  '600588.SH' '600690.SH' '600703.SH' '600745.SH' '600809.SH' '600837.SH'
#  '600848.SH' '600886.SH' '600887.SH' '600926.SH' '600958.SH' '601006.SH'
#  '601088.SH' '601166.SH' '601169.SH' '601238.SH' '601318.SH' '601319.SH'
#  '601336.SH' '601398.SH' '601555.SH' '601601.SH' '601628.SH' '601788.SH'
#  '601838.SH' '601857.SH' '601872.SH' '601899.SH' '601919.SH' '601990.SH'
#  '601998.SH' '603233.SH' '603799.SH' '603833.SH']
# 82

# %%
# 根据股票代码划分数据
for i, stock_i in enumerate(stocks_code):
    stock_i_data = df[df['kdcode'].isin([stock_i])]
    exec("train_df%s = stock_i_data"%i)

# %% [markdown]
# * 测试集

# %%
df2 = pd.read_csv("./data/test.csv", usecols=[0,1,10,11,12,13])
stocks_code2 = df2["kdcode"].unique()

# 根据股票代码划分数据
for i, stock_i in enumerate(stocks_code2):
    stock_i_data = df2[df2['kdcode'].isin([stock_i])]
    exec("test_df%s = stock_i_data" % i)

# %% [markdown]
# 共82支股票
#
# 训练集按股票分为`train_df0`~`train_df81`
#
# 测试集按股票分为`test_df0`~`test_df81`
#
# ### 1.2 将原始数据改造为LSTM网络的输入

# %%
feanum=4 # 一共有多少特征
window=20 # 时间窗设置

# %% [markdown]
# 分割出window个时间窗的数据为输入的`X`
#
# 紧接着的那条数据为标签`Y`
#
# 因此需要将每只股票的数据按照时间(日期)分割成`window + 1`长度的数据

# %%
import numpy as np

trainResult = []
for i in range(stock_num): # 遍历训练集所有股票的DataFrame
    exec("trainData = train_df%s.values" % i)
    sequence_length = window + 1
    trainData = trainData[:,2:] # 去除股票代码、日期两字段
    for index in range(len(trainData) - sequence_length + 1):
        trainResult.append(trainData[index: index + sequence_length])

trainResult = np.array(trainResult)
trainResult.shape
# Out:
# (79934, 21, 4)

# %%
testResult = []
for i in range(stock_num): # 遍历训练集所有股票的DataFrame
    exec("testData = test_df%s.values" % i)
    sequence_length = window + 1
    testData = testData[:,2:] # 去除股票代码、日期两字段
    for index in range(len(testData) - sequence_length + 1):
        testResult.append(testData[index: index + sequence_length])

testResult = np.array(testResult)
testResult.shape
# Out:
# (18265, 21, 4)

# %% [markdown]
# 分割`X`, `Y`

# %%
X_train = trainResult[:, :-1, :]
Y_train = trainResult[:, -1, 0]
X_test = testResult[:, :-1, :]
Y_test = testResult[:, -1, 0]

X_train = X_train.astype('float64')
Y_train = Y_train.astype('float64')
X_test = X_test.astype('float64')
Y_test = Y_test.astype('float64')

print("训练集X：" + str(X_train.shape))
print("训练集Y：" + str(Y_train.shape))
print("测试集X：" + str(X_test.shape))
print("测试集Y：" + str(Y_test.shape))
# Out:
# 训练集X：(79934, 20, 4)
# 训练集Y：(79934,)
# 测试集X：(18265, 20, 4)
# 测试集Y：(18265,)

# %% [markdown]
# ## 2. 模型构建与训练

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import GRU

#建立、训练模型过程
d = 0.0001
model = Sequential()#建立层次模型
model.add(GRU(64, input_shape=(window, feanum), return_sequences=True))#建立LSTM层
model.add(Dropout(d))#建立的遗忘层
model.add(GRU(16, input_shape=(window, feanum), return_sequences=False))#建立LSTM层
model.add(Dropout(d))#建立的遗忘层
model.add(Dense(4,kernel_initializer='uniform',activation='relu'))   #建立全连接层     
model.add(Dense(1,kernel_initializer='uniform',activation='relu'))
model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])
model.fit(X_train, Y_train, epochs =100, batch_size = 256) #训练模型epochs次
# Out:
# Epoch 1/100
# 313/313 [==============================] - 9s 30ms/step - loss: 0.0015 - accuracy: 1.2510e-05
# Epoch 2/100
# 313/313 [==============================] - 9s 30ms/step - loss: 1.9468e-05 - accuracy: 2.5021e-05
# Epoch 3/100
# 313/313 [==============================] - 9s 30ms/step - loss: 1.0343e-05 - accuracy: 2.5021e-05
# Epoch 4/100
# 313/313 [==============================] - 10s 31ms/step - loss: 8.7268e-06 - accuracy: 2.5021e-05
# Epoch 5/100
# 313/313 [==============================] - 9s 29ms/step - loss: 9.5077e-06 - accuracy: 2.5021e-05
# Epoch 6/100
# 313/313 [==============================] - 9s 29ms/step - loss: 7.4789e-06 - accuracy: 2.5021e-05
# Epoch 7/100
# 313/313 [==============================] - 10s 31ms/step - loss: 7.9991e-06 - accuracy: 2.5021e-05
# Epoch 8/100
# 313/313 [==============================] - 9s 30ms/step - loss: 7.9647e-06 - accuracy: 2.5021e-05
# Epoch 9/100
# 313/313 [==============================] - 10s 31ms/step - loss: 6.1290e-06 - accuracy: 2.5021e-05
# Epoch 10/100
# 313/313 [==============================] - 10s 32ms/step - loss: 6.9403e-06 - accuracy: 2.5021e-05
# Epoch 11/100
# 313/313 [==============================] - 10s 31ms/step - loss: 6.0991e-06 - accuracy: 2.5021e-05
# Epoch 12/100
# 313/313 [==============================] - 10s 30ms/step - loss: 5.2290e-06 - accuracy: 2.5021e-05
# Epoch 13/100
# 313/313 [==============================] - 9s 30ms/step - loss: 5.3332e-06 - accuracy: 2.5021e-05
# Epoch 14/100
# 313/313 [==============================] - 9s 30ms/step - loss: 5.7600e-06 - accuracy: 2.5021e-05
# Epoch 15/100
# 313/313 [==============================] - 9s 30ms/step - loss: 5.3608e-06 - accuracy: 2.5021e-05
# Epoch 16/100
# 313/313 [==============================] - 9s 30ms/step - loss: 4.7739e-06 - accuracy: 2.5021e-05
# Epoch 17/100
# 313/313 [==============================] - 9s 29ms/step - loss: 5.1099e-06 - accuracy: 2.5021e-05
# Epoch 18/100
# 313/313 [==============================] - 10s 30ms/step - loss: 5.3596e-06 - accuracy: 2.5021e-05
# Epoch 19/100
# 313/313 [==============================] - 9s 30ms/step - loss: 4.5071e-06 - accuracy: 2.5021e-05
# Epoch 20/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.4204e-06 - accuracy: 2.5021e-05
# Epoch 21/100
# 313/313 [==============================] - 9s 27ms/step - loss: 4.5305e-06 - accuracy: 2.5021e-05
# Epoch 22/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.8931e-06 - accuracy: 2.5021e-05
# Epoch 23/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.3518e-06 - accuracy: 2.5021e-05
# Epoch 24/100
# 313/313 [==============================] - 9s 29ms/step - loss: 4.7201e-06 - accuracy: 2.5021e-05
# Epoch 25/100
# 313/313 [==============================] - 9s 29ms/step - loss: 4.1905e-06 - accuracy: 2.5021e-05
# Epoch 26/100
# 313/313 [==============================] - 9s 30ms/step - loss: 4.3615e-06 - accuracy: 2.5021e-05
# Epoch 27/100
# 313/313 [==============================] - 9s 29ms/step - loss: 4.6249e-06 - accuracy: 2.5021e-05
# Epoch 28/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.5553e-06 - accuracy: 2.5021e-05
# Epoch 29/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.0762e-06 - accuracy: 2.5021e-05
# Epoch 30/100
# 313/313 [==============================] - 10s 31ms/step - loss: 3.9811e-06 - accuracy: 2.5021e-05
# Epoch 31/100
# 313/313 [==============================] - 10s 32ms/step - loss: 4.1995e-06 - accuracy: 2.5021e-05
# Epoch 32/100
# 313/313 [==============================] - 9s 30ms/step - loss: 3.7575e-06 - accuracy: 2.5021e-05
# Epoch 33/100
# 313/313 [==============================] - 10s 31ms/step - loss: 4.4231e-06 - accuracy: 2.5021e-05
# Epoch 34/100
# 313/313 [==============================] - 9s 29ms/step - loss: 4.2752e-06 - accuracy: 2.5021e-05
# Epoch 35/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.0864e-06 - accuracy: 2.5021e-05
# Epoch 36/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.8318e-06 - accuracy: 2.5021e-05
# Epoch 37/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.7332e-06 - accuracy: 2.5021e-05
# Epoch 38/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.5218e-06 - accuracy: 2.5021e-05
# Epoch 39/100
# 313/313 [==============================] - 8s 27ms/step - loss: 4.2026e-06 - accuracy: 2.5021e-05
# Epoch 40/100
# 313/313 [==============================] - 8s 27ms/step - loss: 4.4274e-06 - accuracy: 2.5021e-05
# Epoch 41/100
# 313/313 [==============================] - 8s 27ms/step - loss: 4.4935e-06 - accuracy: 2.5021e-05
# Epoch 42/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.7816e-06 - accuracy: 2.5021e-05
# Epoch 43/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.4589e-06 - accuracy: 2.5021e-05
# Epoch 44/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.8216e-06 - accuracy: 2.5021e-05
# Epoch 45/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.8701e-06 - accuracy: 2.5021e-05
# Epoch 46/100
# 313/313 [==============================] - 8s 27ms/step - loss: 3.6522e-06 - accuracy: 2.5021e-05
# Epoch 47/100
# 313/313 [==============================] - 8s 27ms/step - loss: 4.3138e-06 - accuracy: 2.5021e-05
# Epoch 48/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.7611e-06 - accuracy: 2.5021e-05
# Epoch 49/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.7624e-06 - accuracy: 2.5021e-05
# Epoch 50/100
# 313/313 [==============================] - 9s 30ms/step - loss: 4.1597e-06 - accuracy: 2.5021e-05
# Epoch 51/100
# 313/313 [==============================] - 9s 30ms/step - loss: 3.7097e-06 - accuracy: 2.5021e-05
# Epoch 52/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.9447e-06 - accuracy: 2.5021e-05
# Epoch 53/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.8171e-06 - accuracy: 2.5021e-05
# Epoch 54/100
# 313/313 [==============================] - 9s 30ms/step - loss: 3.6041e-06 - accuracy: 2.5021e-05
# Epoch 55/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.8656e-06 - accuracy: 2.5021e-05
# Epoch 56/100
# 313/313 [==============================] - 9s 30ms/step - loss: 4.6989e-06 - accuracy: 2.5021e-05
# Epoch 57/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.4110e-06 - accuracy: 2.5021e-05
# Epoch 58/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.6476e-06 - accuracy: 2.5021e-05
# Epoch 59/100
# 313/313 [==============================] - 9s 29ms/step - loss: 4.0092e-06 - accuracy: 2.5021e-05
# Epoch 60/100
# 313/313 [==============================] - 9s 30ms/step - loss: 4.0074e-06 - accuracy: 2.5021e-05
# Epoch 61/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.7378e-06 - accuracy: 2.5021e-05
# Epoch 62/100
# 313/313 [==============================] - 9s 30ms/step - loss: 3.6228e-06 - accuracy: 2.5021e-05
# Epoch 63/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.6440e-06 - accuracy: 2.5021e-05
# Epoch 64/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.3433e-06 - accuracy: 2.5021e-05
# Epoch 65/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.1990e-06 - accuracy: 2.5021e-05
# Epoch 66/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.5864e-06 - accuracy: 2.5021e-05
# Epoch 67/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.1117e-06 - accuracy: 2.5021e-05
# Epoch 68/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.9945e-06 - accuracy: 2.5021e-05
# Epoch 69/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.8921e-06 - accuracy: 2.5021e-05
# Epoch 70/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.0257e-06 - accuracy: 2.5021e-05
# Epoch 71/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.6017e-06 - accuracy: 2.5021e-05
# Epoch 72/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.7079e-06 - accuracy: 2.5021e-05
# Epoch 73/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.8580e-06 - accuracy: 2.5021e-05
# Epoch 74/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.6132e-06 - accuracy: 2.5021e-05
# Epoch 75/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.2944e-06 - accuracy: 2.5021e-05
# Epoch 76/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.8018e-06 - accuracy: 2.5021e-05
# Epoch 77/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.7488e-06 - accuracy: 2.5021e-05
# Epoch 78/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.7967e-06 - accuracy: 2.5021e-05
# Epoch 79/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.6604e-06 - accuracy: 2.5021e-05
# Epoch 80/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.8581e-06 - accuracy: 2.5021e-05
# Epoch 81/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.5296e-06 - accuracy: 2.5021e-05
# Epoch 82/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.8636e-06 - accuracy: 2.5021e-05
# Epoch 83/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.3709e-06 - accuracy: 2.5021e-05
# Epoch 84/100
# 313/313 [==============================] - 10s 32ms/step - loss: 3.9790e-06 - accuracy: 2.5021e-050s - loss: 3.9790e-06 - accuracy: 2.5021e-
# Epoch 85/100
# 313/313 [==============================] - 10s 33ms/step - loss: 3.5349e-06 - accuracy: 2.5021e-05
# Epoch 86/100
# 313/313 [==============================] - 10s 33ms/step - loss: 3.4568e-06 - accuracy: 2.5021e-05
# Epoch 87/100
# 313/313 [==============================] - 10s 31ms/step - loss: 3.5562e-06 - accuracy: 2.5021e-05
# Epoch 88/100
# 313/313 [==============================] - 9s 29ms/step - loss: 3.5861e-06 - accuracy: 2.5021e-05
# Epoch 89/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.3835e-06 - accuracy: 2.5021e-05
# Epoch 90/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.3966e-06 - accuracy: 2.5021e-05
# Epoch 91/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.7060e-06 - accuracy: 2.5021e-05
# Epoch 92/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.9338e-06 - accuracy: 2.5021e-05
# Epoch 93/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.3596e-06 - accuracy: 2.5021e-05
# Epoch 94/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.2695e-06 - accuracy: 2.5021e-05
# Epoch 95/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.5298e-06 - accuracy: 2.5021e-05
# Epoch 96/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.4179e-06 - accuracy: 2.5021e-05
# Epoch 97/100
# 313/313 [==============================] - 9s 28ms/step - loss: 4.5661e-06 - accuracy: 2.5021e-05
# Epoch 98/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.4768e-06 - accuracy: 2.5021e-05
# Epoch 99/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.4694e-06 - accuracy: 2.5021e-05
# Epoch 100/100
# 313/313 [==============================] - 9s 28ms/step - loss: 3.6057e-06 - accuracy: 2.5021e-05

# %%
#总结模型
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 20, 64)            13440
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 64)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 16)                3936
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 68
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 17,449
# Trainable params: 17,449
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. 模型训练结果
# * 训练集

# %%
#在训练集上的拟合结果
Y_train_predict=model.predict(X_train)[:,0]
Y_train = Y_train

# %%
import matplotlib.pyplot as plt

draw=pd.concat([pd.DataFrame(Y_train),pd.DataFrame(Y_train_predict)],axis=1)
draw.iloc[:300,0].plot(figsize=(12,6))
draw.iloc[:300,1].plot(figsize=(12,6))
plt.legend(('real', 'predict'),loc='upper right',fontsize='15')
plt.title("Train Data",fontsize='30') #添加标题
#展示在训练集上的表现
# Out:
# Text(0.5, 1.0, 'Train Data')

# %%
#在测试集上的预测
Y_test_predict=model.predict(X_test)[:,0]
Y_test=Y_test

# %%
draw=pd.concat([pd.DataFrame(Y_test),pd.DataFrame(Y_test_predict)],axis=1);
draw.iloc[:100,0].plot(figsize=(12,6))
draw.iloc[:100,1].plot(figsize=(12,6))
plt.legend(('real', 'predict'),loc='upper right',fontsize='15')
plt.title("Test Data",fontsize='30') #添加标题
# 展示在测试集上的表现
# Out:
# Text(0.5, 1.0, 'Test Data')

# %%
#输出结果
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import math

print('训练集上的MAE/MSE')
print(mean_absolute_error(Y_train_predict, Y_train))
print(mean_squared_error(Y_train_predict, Y_train) )

print('测试集上的MAE/MSE')
print(mean_absolute_error(Y_test_predict, Y_test))
print(mean_squared_error(Y_test_predict, Y_test) )

# 做差转换为涨跌数据
Y_var_test=Y_test[1:]-Y_test[:len(Y_test)-1]
Y_var_predict=Y_test_predict[1:]-Y_test_predict[:len(Y_test_predict)-1]

txt=np.zeros(len(Y_var_test))
for i in range(len(Y_var_test-1)):
    txt[i]=np.sign(Y_var_test[i])==np.sign(Y_var_predict[i]) # 判断符号是否相等
result=sum(txt)/len(txt)
print('预测涨跌正确:',result)
# Out:
# 训练集上的MAE/MSE
# 0.0006634360487384991
# 2.8817711981804074e-06
# 测试集上的MAE/MSE
# 0.0008825562302063399
# 5.391570200665545e-06
# 预测涨跌正确: 0.4802890932982917

# %% [markdown]
# > 结果汇总
#
# | 模型 | window | 训练集MAE             | 训练集MSE              | 测试集MAE             | 测试集MSE              | 预测涨跌准确率      |
# | ---- | ------ | --------------------- | ---------------------- | --------------------- | ---------------------- | ------------------- |
# | GRU  | 5      | 0.0011636380434723794 | 3.5832097623007097e-06 | 0.0013400792617884532 | 6.051869212817353e-06  | 0.481122396634862   |
# | GRU  | 10     | 0.0006846045697494243 | 2.783158476830706e-06  | 0.0008838190573163694 | 4.9900897278278514e-06 | 0.47856843429050516 |
# | GRU  | 20     | 0.0006634360487384991 | 2.8817711981804074e-06 | 0.0008825562302063399 | 5.391570200665545e-06  | 0.4802890932982917  |
